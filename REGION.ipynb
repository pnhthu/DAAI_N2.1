# %%
import pandas as pd

# Đường dẫn file đầu ra
csv_region_path = '/content/REGION.csv'

# Tạo dữ liệu bảng REGION (Chỉ có 3 miền)
region_df = pd.DataFrame({
    'region_id':   ['MB',       'MT',         'MN'],
    'region_name': ['Mien Bac', 'Mien Trung', 'Mien Nam']
})

# Xuất file CSV
region_df.to_csv(csv_region_path, index=False, encoding='utf-8-sig')
print('Da tao file REGION.csv thanh cong.')
# Out:
# Da tao file REGION.csv thanh cong.
